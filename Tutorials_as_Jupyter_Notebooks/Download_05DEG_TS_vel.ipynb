# %%
from ecco_download import *

# %%
ecco_podaac_download(ShortName="ECCO_L4_OCEAN_VEL_05DEG_MONTHLY_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_OCEAN_VEL_05DEG_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_OCEAN_VEL_05DEG_MONTHLY_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 312
#
# OCEAN_VELOCITY_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1992-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1993-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1994-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1995-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1996-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1997-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1998-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_1999-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2000-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2001-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2002-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2003-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2004-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2005-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2006-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# OCEAN_VELOCITY_mon_mean_2007-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# OCEAN_VELOCITY_mon_mean_2007-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2007-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2007-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2007-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
#
# OCEAN_VELOCITY_mon_mean_2007-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# DL Progress:   0%|                                 | 0/312 [00:00<?, ?it/s]
# OCEAN_VELOCITY_mon_mean_2007-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2007-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2007-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2007-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# OCEAN_VELOCITY_mon_mean_2007-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2007-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
#
# OCEAN_VELOCITY_mon_mean_2008-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2008-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2009-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2010-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2011-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2012-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2013-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2014-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2015-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2016-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_VELOCITY_mon_mean_2017-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# DL Progress: 100%|####################| 312/312 [00:00<00:00, 31806.69it/s]
#
# =====================================
# total downloaded: 0.0 Mb
# avg download speed: 0.0 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_TEMP_SALINITY_05DEG_MONTHLY_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_TEMP_SALINITY_05DEG_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_TEMP_SALINITY_05DEG_MONTHLY_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 312
# DL Progress:  25%|######                  | 78/312 [01:56<05:49,  1.49s/it]
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1993-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1994-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1995-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1996-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1997-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1998-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_1999-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2000-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2001-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2002-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2003-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2004-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2005-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2006-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2007-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2008-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2009-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2010-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2011-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2012-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2013-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2014-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2015-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2016-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_TEMPERATURE_SALINITY_mon_mean_2017-12_ECCO_V4r4_latlon_0p50deg.nc
#
# =====================================
# total downloaded: 4554.47 Mb
# avg download speed: 4.6 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 312
# DL Progress: 100%|#######################| 312/312 [22:57<00:00,  4.41s/it]
#
# =====================================
# total downloaded: 13898.97 Mb
# avg download speed: 10.09 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_OCEAN_3D_MIX_COEFFS_05DEG_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_OCEAN_3D_MIX_COEFFS_05DEG_V4R4
# {'ShortName': 'ECCO_L4_OCEAN_3D_MIX_COEFFS_05DEG_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 1
# DL Progress: 100%|###########################| 1/1 [00:10<00:00, 10.32s/it]
#
# =====================================
# total downloaded: 38.84 Mb
# avg download speed: 3.76 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_OCEAN_VEL_LLC0090GRID_MONTHLY_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_OCEAN_VEL_LLC0090GRID_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_OCEAN_VEL_LLC0090GRID_MONTHLY_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 312
# DL Progress:  21%|#####1                  | 67/312 [02:47<10:12,  2.50s/it]
# downloading OCEAN_VELOCITY_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-02_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-03_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-04_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-05_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-06_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-07_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-08_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-09_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-10_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-11_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1992-12_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1992-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-01_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-02_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-03_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-04_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-05_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-06_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-07_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-08_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-09_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-10_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-11_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1993-12_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1993-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-01_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-02_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-03_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-04_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-05_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-06_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-07_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-08_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-09_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-10_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-11_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1994-12_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1994-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-01_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-02_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-03_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-04_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-05_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-06_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-07_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-08_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-09_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-10_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-11_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1995-12_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1995-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-01_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-02_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-03_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-04_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-05_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-06_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-07_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-08_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-09_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-10_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-11_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1996-12_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1996-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-01_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-02_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-03_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-04_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-05_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-06_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-07_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1997-09_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-10_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-11_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1997-12_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1997-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1998-01_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1998-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1998-02_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1998-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1998-03_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1998-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1998-04_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1998-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1998-05_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_1998-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_1998-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1998-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1998-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1998-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1998-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1998-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1998-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_1999-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2000-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2001-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2002-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2003-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2004-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2005-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2006-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2007-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2008-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2009-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-03_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_VELOCITY_mon_mean_2010-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# downloading OCEAN_VELOCITY_mon_mean_2010-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2010-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2011-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2012-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2013-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2014-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2015-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2016-12_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-01_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-02_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-03_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-04_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-05_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-06_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-07_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-08_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-09_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-10_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-11_ECCO_V4r4_native_llc0090.nc
# downloading OCEAN_VELOCITY_mon_mean_2017-12_ECCO_V4r4_native_llc0090.nc
#
# =====================================
# total downloaded: 7193.31 Mb
# avg download speed: 5.45 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_GEOMETRY_LLC0090GRID_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_GEOMETRY_LLC0090GRID_V4R4
# {'ShortName': 'ECCO_L4_GEOMETRY_LLC0090GRID_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 1
#
# GRID_GEOMETRY_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# DL Progress: 100%|#########################| 1/1 [00:00<00:00, 1837.99it/s]
#
# =====================================
# total downloaded: 0.0 Mb
# avg download speed: 0.0 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_SSH_LLC0090GRID_MONTHLY_V4R4",\
                    StartDate="2000-01-01",EndDate="2000-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_SSH_LLC0090GRID_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_SSH_LLC0090GRID_MONTHLY_V4R4', 'temporal': '2000-01-01,2000-12-31'}
#
# Total number of matching granules: 13
# DL Progress: 100%|#########################| 13/13 [00:22<00:00,  1.73s/it]
#
# =====================================
# total downloaded: 76.92 Mb
# avg download speed: 3.42 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_STRESS_LLC0090GRID_MONTHLY_V4R4",\
                    StartDate="2000-01-01",EndDate="2000-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_STRESS_LLC0090GRID_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_STRESS_LLC0090GRID_MONTHLY_V4R4', 'temporal': '2000-01-01,2000-12-31'}
#
# Total number of matching granules: 13
# DL Progress: 100%|#########################| 13/13 [00:11<00:00,  1.12it/s]
#
# =====================================
# total downloaded: 77.51 Mb
# avg download speed: 6.66 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 312
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1992-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1993-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# DL Progress:   0%|                                 | 0/312 [00:00<?, ?it/s]
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1994-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1995-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1996-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1997-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1998-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_1999-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2000-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2001-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2002-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2003-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2004-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2005-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2006-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2007-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2008-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2009-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2010-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2011-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2012-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2013-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2014-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2015-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2016-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_BOLUS_VELOCITY_mon_mean_2017-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# DL Progress: 100%|####################| 312/312 [00:00<00:00, 17514.39it/s]
#
# =====================================
# total downloaded: 0.0 Mb
# avg download speed: 0.0 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_DENS_STRAT_PRESS_05DEG_MONTHLY_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_DENS_STRAT_PRESS_05DEG_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_DENS_STRAT_PRESS_05DEG_MONTHLY_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 312
# DL Progress:  24%|#####8                  | 76/312 [03:09<09:47,  2.49s/it]
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1992-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1992-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1993-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1993-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1994-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1994-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1995-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1995-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1996-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1996-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1997-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1997-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-07_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-08_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-09_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-10_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-11_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1998-12_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1998-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-01_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1999-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-02_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1999-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-03_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1999-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-04_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1999-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-05_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1999-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-06_ECCO_V4r4_latlon_0p50deg.nc
#
# OCEAN_DENS_STRAT_PRESS_mon_mean_1999-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_1999-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2000-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2001-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2002-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2003-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2004-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2005-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2006-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2007-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2008-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2009-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2010-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2011-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2012-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2013-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2014-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2015-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2016-12_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-01_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-02_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-03_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-04_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-05_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-06_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-07_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-08_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-09_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-10_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-11_ECCO_V4r4_latlon_0p50deg.nc
# downloading OCEAN_DENS_STRAT_PRESS_mon_mean_2017-12_ECCO_V4r4_latlon_0p50deg.nc
#
# =====================================
# total downloaded: 7498.35 Mb
# avg download speed: 6.39 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_GEOMETRY_05DEG_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_GEOMETRY_05DEG_V4R4
# {'ShortName': 'ECCO_L4_GEOMETRY_05DEG_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 1
# DL Progress: 100%|###########################| 1/1 [00:03<00:00,  3.70s/it]
#
# =====================================
# total downloaded: 1.9 Mb
# avg download speed: 0.51 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_MIXED_LAYER_DEPTH_05DEG_MONTHLY_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_MIXED_LAYER_DEPTH_05DEG_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_MIXED_LAYER_DEPTH_05DEG_MONTHLY_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 312
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1992-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# DL Progress:   0%|                                 | 0/312 [00:00<?, ?it/s]
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1993-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1994-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1995-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1996-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1997-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1998-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_1999-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2000-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2001-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2002-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2003-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2004-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2005-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2006-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2007-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2008-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2009-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-02_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-06_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-04_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-10_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-11_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-07_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-03_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2011-01_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-05_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-09_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-08_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
#
# OCEAN_MIXED_LAYER_DEPTH_mon_mean_2010-12_ECCO_V4r4_latlon_0p50deg.nc already exists, and force=False, not re-downloading
# DL Progress: 100%|#######################| 312/312 [01:02<00:00,  5.00it/s]
#
# =====================================
# total downloaded: 31.1 Mb
# avg download speed: 0.5 Mb/s

# %%
ecco_podaac_download(ShortName="ECCO_L4_OCEAN_3D_MIX_COEFFS_LLC0090GRID_V4R4",\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /Users/boerzhang/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_OCEAN_3D_MIX_COEFFS_LLC0090GRID_V4R4
# {'ShortName': 'ECCO_L4_OCEAN_3D_MIX_COEFFS_LLC0090GRID_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 1
# DL Progress: 100%|###########################| 1/1 [01:21<00:00, 81.33s/it]
#
# =====================================
# total downloaded: 28.89 Mb
# avg download speed: 0.36 Mb/s
